# %% [markdown]
# ## **Clustering por K-means**

# %% [markdown]
# #### **Carga de librerías & datos**

# %%
import pandas as pd, matplotlib.pyplot as plt, seaborn as sns, numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

df = pd.read_csv('BetterLife_cleaned.csv')

# %% [markdown]
# #### **K-Means**

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# Seleccionar las columnas numéricas para el clustering
numeric_columns = df.select_dtypes(include=['float64']).columns
data = df[numeric_columns]

# Escalar los datos
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# Aplicar K-means
kmeans = KMeans(n_clusters = 4, random_state = 50)  # Cambia n_clusters según el número de grupos deseados
df['Cluster'] = kmeans.fit_predict(scaled_data)

df.sort_values(by='Cluster', ascending= True, inplace=True)

# Mostrar los países con sus respectivos clusters
print(df[['Country', 'Cluster']])

fig, ax = plt.subplots(figsize=(40, 6))
sns.scatterplot(data=df, x='Country', y='Cluster', hue='Cluster', palette='Set1', ax=ax)
None
# Out:
#            Country  Cluster
# 13           Japan        0
# 22        Portugal        0
# 25          Sweden        1
# 20          Norway        1
# 19     New Zealand        1
# 18     Netherlands        1
# 16      Luxembourg        1
# 26  United Kingdom        1
# 11         Ireland        1
# 0        Australia        1
# 27   United States        1
# 8          Germany        1
# 1          Austria        1
# 7           France        1
# 6          Finland        1
# 2          Belgium        1
# 4          Denmark        1
# 3           Canada        1
# 14     South Korea        2
# 24           Spain        3
# 23        Slovenia        3
# 10         Hungary        3
# 9           Greece        3
# 17          Mexico        3
# 15       Lithuania        3
# 12           Italy        3
# 21          Poland        3
# 5          Estonia        3

# %% [markdown]
# #### **Exportación del dataset**

# %%
df.to_csv('BetterLife_clustered.csv', index = False)
