# %%
import pandas as pd

def df_to_sorted_dict(df):
    d = dict()
    for i, row in df.iterrows():
        for variable, valor in row.items():
            d[variable] = valor
    return dict(sorted(d.items(), key=lambda item: item[1], reverse=True))

user_input = pd.DataFrame([{'Education': 3,
                                                'Jobs': 5,
                                                'Income': 4,
                                                'Safety': 9,
                                                'Health': 5.6,
                                                'Environment': 1,
                                                'Civic engagement': 10,
                                                'Accessibility to services': 8,
                                                'Housing': 6,
                                                'Community': 4}])

df_to_sorted_dict(user_input)
# Out:
# {'Civic engagement': 10.0,
#  'Safety': 9.0,
#  'Accessibility to services': 8.0,
#  'Housing': 6.0,
#  'Health': 5.6,
#  'Jobs': 5.0,
#  'Income': 4.0,
#  'Community': 4.0,
#  'Education': 3.0,
#  'Environment': 1.0}

# %%
import matplotlib.pyplot as plt

def graficar_scatter(input, pais):
    # Esta función recibe dos diccionarios con los mismos índices(las varaibles) y gráfica sus valores en un scatter plot
    fig, ax = plt.subplots()
    plt.plot(input.keys(), input.values(), label='Input del usuario', color='blue')
    plt.plot(input.keys(), pais.values(), label='Valores del país', color='red')
    plt.xlabel('Variables')
    plt.ylabel('Valores')
    plt.title(f'Comparación de valores entre {pais} y el input del usuario.')
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
def df_country_to_dict(df, pais):
	# Esta función recibe un df con todos los países y sus valores, y devuelve un diccionario del tipo {variable: valor} para el país buscado como parámetro
	d = dict()
	for i, row in df.iterrows():
		if row['Country'] == pais:
			for variable, valor in row.items():
				if variable != 'Country':
					d[variable] = float(valor)
			break
		else:
			continue

	return d

top = ['Colombia', 'Italia', 'España']
df = pd.read_csv('BetterLife.csv')
dic_top1 = df_country_to_dict(df, top[0])

print(dic_top1)
# Out:
# {'Education': 3.4, 'Jobs': 0.9, 'Income': 0.9, 'Safety': 0.0, 'Health': 4.3, 'Environment': 5.2, 'Civic engagement': 3.4, 'Accessiblity to services': 1.2, 'Housing': 0.0, 'Community': 3.1, 'Life satisfaction': 3.5}

# %%
from translate import Translator
def traducir_pal(str, entrada = 'en', salida = 'es'):
    # Esta función recibe un string y un diccionario de entrada y otro de salida, y traduce el string de entrada al de salida
    translator = Translator(from_lang=entrada, to_lang=salida)
    try:
        return translator.translate(str)
    except:
        return str

def traducir_lista(lista, entrada = 'en', salida = 'es'):
    # Esta función recibe una lista de strings y un diccionario de entrada y otro de salida, y traduce la lista de entrada al de salida
    try:
        return [traducir_pal(i, entrada, salida) for i in lista]
    except:
        return lista

# %%
def graficar_scatter(input, dic_pais, pais):
    # Esta función recibe dos diccionarios con los mismos índices(las varaibles) y gráfica sus valores en un scatter plot
    del dic_pais['Life satisfaction']
    fig, ax = plt.subplots()
    plt.plot(traducir_lista(list(input.keys())), traducir_lista(list(input.values())), 'ro', label='Input del usuario', color='blue')
    plt.plot(traducir_lista(list(input.keys())), traducir_lista(list(dic_pais.values())), 'bo', label='Valores del país', color='red')
    plt.xlabel('Variables')
    plt.ylabel('Valores')
    plt.title(f'Comparación de valores entre {traducir_pal(pais)} y el input del usuario.')
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

import numpy as np
from numpy import linalg as la

def graficar_regresion(input, dic_pais, pais):
    # Esta función recibe dos diccionarios con los mismos índices(las variables) y gráfica sus valores en un scatter plot
    del dic_pais['Life satisfaction']
    
    A = np.arange(1, 11).reshape(10, 1)
    b_input = np.array([input.values()])
    b_pais = np.array([dic_pais.values()])
    
    x_input = la.inv(A.T @ A) @ A.T @ b_input
    x_pais = la.inv(A.T @ A) @ A.T @ b_pais
    
    
    fig, ax = plt.subplots()
    plt.plot(traducir_lista(list(input.keys())), A @ x_input, 'ro', label='Input del usuario', color='blue')
    plt.plot(traducir_lista(list(input.keys())), A @ x_pais, 'bo', label='Valores del país', color='red')
    plt.xlabel('Variables')
    plt.ylabel('Valores')
    plt.title(f'Comparación de valores entre {traducir_pal(pais)} y el input del usuario.')
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def graficar_histograma(input, dic_pais, pais):
    # Asegurarse de que las claves coinciden
    claves = input.keys()
    
    # Obtener los valores
    valores_usuario = np.array([input[k] for k in claves])
    valores_pais = np.array([dic_pais[k] for k in claves])
    
    # Sumar ambos vectores
    valores_combinados = valores_usuario + valores_pais
    
    # Definir posiciones para las barras
    x = np.arange(len(claves))
    
    # Crear el gráfico
    plt.figure(figsize=(10, 6))
    plt.bar(x, valores_usuario, width=0.4, label='Usuario', align='center')
    plt.bar(x, valores_pais, width=0.4, bottom=valores_usuario, label=pais, align='center')
    
    # Etiquetas
    plt.xticks(x, claves, rotation=45)
    plt.ylabel("Valor")
    plt.title("Comparación de usuario y país: suma de histogramas")
    plt.legend()
    plt.tight_layout()
    
    # Mostrar
    plt.show()

# %%
x = np.array([1,2,3,4,5]) 
y = np.array([1,4,9,16,25])        
z = np.array([1,8,27,64,125])

fig, ax = plt.subplots() # creamos los objetos Figure y Axes

ax.bar(x,y)              # Representar valores y mediante barras                                
ax.bar(x, z, bottom=y)   # Representar valores z apilados sobre los de y
ax.set_title("$x^2$ + $x^3$")         
ax.set_xlabel("x")                
ax.set_ylabel("y")                 
ax.legend(["$x^2$", "$x^3$"])                                  
None

def graficar_histograma(input, dic_pais, pais):
    claves = input.keys()
    valores_usuario = np.array([k for k in input.values()])
    valores_pais = np.array([k for k in dic_pais.values()])
    
    plt.figure()
    plt.bar(claves, valores_usuario, label='Usuario')
    plt.bar(claves, valores_pais, label=pais, bottom=valores_usuario)
    plt.xlabel('Variables')
    plt.ylabel('Valores')
    plt.title(f'Comparación de valores entre {traducir_pal(pais)} y el input del usuario.')
    plt.legend()

# %%
def graficar_regresion(input, dic_pais, pais):
    # Obtener claves comunes
    claves_comunes = list(set(input.keys()) & set(dic_pais.keys()))

    if len(claves_comunes) < 2:
        raise ValueError("Se necesitan al menos 2 variables comunes para ajustar una recta de regresión.")

    # Ordenar las claves por el valor del input (usuario), de mayor a menor
    claves_ordenadas = sorted(claves_comunes, key=lambda k: input[k], reverse=True)

    # Extraer valores ordenados
    b_input = np.array([input[k] for k in claves_ordenadas]).reshape(-1, 1)
    b_pais = np.array([dic_pais[k] for k in claves_ordenadas]).reshape(-1, 1)

    n = len(claves_ordenadas)
    a = np.arange(1, n + 1).reshape(-1, 1)
    A = np.hstack([np.ones_like(a), a])  # diseño: [1, x]

    # Ajuste por mínimos cuadrados
    x_input = la.inv(A.T @ A) @ A.T @ b_input
    x_pais = la.inv(A.T @ A) @ A.T @ b_pais

    # Predicciones
    y_input = (A @ x_input).flatten()
    y_pais = (A @ x_pais).flatten()

    # Gráfico
    fig, ax = plt.subplots()
    ax.hist(claves_ordenadas, y_input, label='Regresión usuario', color='blue', linestyle='-')
    ax.hist(claves_ordenadas, y_pais, label=f'Regresión {pais}', color='red', linestyle='-')

    # Etiquetas y formato
    ax.set_xlabel('Variables')
    ax.set_ylabel('Valores')
    ax.set_title(f'Comparación de valores entre {pais} y el input del usuario.')
    ax.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    st.pyplot(fig)
