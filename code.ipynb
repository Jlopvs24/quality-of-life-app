# %% [markdown]
# **Carga de datos y librerías**

# %%
import pandas as pd, matplotlib.pyplot as plt, seaborn as sns

df = pd.read_csv('BetterLife_cleaned.csv')
df_numeric = df.select_dtypes(include=['float64', 'int64'])

# %% [markdown]
# **Descripción de los datos**

# %%
df.describe()
# Out:
#        GDP per capita (EURO)  Dwellings without basic facilities  \
# count              28.000000                           28.000000
# mean                3.149085                            0.938578
# std                 2.327309                            2.036527
# min                 0.000000                            0.000000
# 25%                 1.512744                            0.077220
# 50%                 2.975330                            0.193050
# 75%                 3.884036                            0.762522
# max                10.000000                           10.000000
#
#        Housing expenditure  Rooms per person  \
# count            28.000000         28.000000
# mean              5.492372          4.619048
# std               2.180796          2.480731
# min               0.000000          0.000000
# 25%               4.320388          3.166667
# 50%               5.485437          4.666667
# 75%               6.893204          6.000000
# ...

# %% [markdown]
# **Matriz de correlaciones**

# %%
plt.figure(figsize = (25, 25))
matriz = df_numeric.corr(method = 'pearson')
sns.heatmap(matriz, cmap = 'coolwarm', annot = True)
plt.show()

# %% [markdown]
# ## **Scatter plot de las variables de cada país**

# %%
# Vamos a plotear, para cada país, los valores de cada una de sus variables

# Crea una lista con los nombres de las variables
variables = list(df.columns)
# Crea una lista con los nombres de los países
paises = list(df['Country'])
"""
for variable in variables:
	# Crea una figura con un tamaño específico
	plt.figure(figsize=(10, 5))
	# Crea un gráfico de barras
	sns.barplot(x=paises, y=df[variable])
	# Rota las etiquetas del eje x
	plt.xticks(rotation=90)
	# Añade un título al gráfico
	plt.title(variable)
	# Muestra el gráfico
	plt.show()
"""
# Out:
# '\nfor variable in variables:\n\t# Crea una figura con un tamaño específico\n\tplt.figure(figsize=(10, 5))\n\t# Crea un gráfico de barras\n\tsns.barplot(x=paises, y=df[variable])\n\t# Rota las etiquetas del eje x\n\tplt.xticks(rotation=90)\n\t# Añade un título al gráfico\n\tplt.title(variable)\n\t# Muestra el gráfico\n\tplt.show()\n'
